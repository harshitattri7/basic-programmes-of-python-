# %% [markdown]
# SEABORN

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    --------- ----------------------------- 71.7/294.9 kB 975.2 kB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\TECHCADD\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme()
tips=sns.load_dataset('tips')
sns.relplot(
    data=tips,
    x="total_bill",y="tip",col="time",
    hue="smoker",style="smoker",size="size"
)

# %%
import seaborn as sns

tips=sns.load_dataset("tips")
(
    sns.lmplot(data=tips,x="total_bill",y="tip",col="time",hue='smoker')
)

# %%
tips=sns.load_dataset("tips")
(
sns.catplot(data=tips,kind="swarm",x="day",y='total_bill',hue="smoker")
)

# %%
tips=sns.load_dataset("tips")

(
    sns.catplot(data=tips,kind="violin",x="day",y='total_bill',hue="smoker",split=True)
)

# %%
tips=sns.load_dataset("tips")
(
sns.catplot(data=tips,kind="bar",x="day",y='total_bill',hue="smoker")
)

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")
(
sns.lmplot(data=tips,x="total_bill",y='tip',hue="sex",col="time")
)

# %%
tips=sns.load_dataset("tips")
(
sns.lmplot(data=tips,x="total_bill",y='tip',hue="day",col="time")
)

# %%
import seaborn as sns
tips=sns.load_dataset("tips")
(
sns.displot(data=tips,x="total_bill",col="time",kde=True)
)

# %%
aa=sns.load_dataset("penguins")
aa
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
import seaborn as sns
sns.displot(data=aa,x='flipper_length_mm',hue='species',col='species')

# %%
g=sns.relplot(data=aa,x='flipper_length_mm',y="bill_length_mm",col="sex")
g.set_axis_labels("flipper lenght (mm)","bill length (mm)")

# %%
aa=sns.load_dataset("flights")
aa
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.catplot(data=aa,x="month",y="passengers",kind="box")

# %%
sns.relplot(data=aa,x="year",y="passengers",hue="month",kind="line")

# %%
sns.relplot(data=aa,x="month",y="passengers",hue="year",kind="line")

# %%
penguins =sns.load_dataset("penguins")
sns.jointplot(data=penguins,x="flipper_length_mm",y="bill_depth_mm",hue="species")
