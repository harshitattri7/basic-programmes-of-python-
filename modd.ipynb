# %%
import math
print(math.sqrt(4))
# Out:
# 2.0

# %%
import math
print(math.sqrt(5))
# Out:
# 2.23606797749979

# %%
import math
print(math.factorial(4))
# Out:
# 24

# %%
from math import sin,cos
print(sin(1))
print(cos(1))
# Out:
# 0.8414709848078965
# 0.5403023058681398

# %%
import random
print(random.randint(1,20))
# Out:
# 2

# %%
from hhmod import greet
greet('harshit')
# Out:
# 'hello,harshit!'
