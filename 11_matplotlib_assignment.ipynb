# %%
# _____________________________________________matplotlib assignment__________________________________________________________________

# %%
# task1

# %%
import matplotlib.pyplot as plt

# %%
x=[0,1,2,3,4,5]
y=[0,1,4,9,16,25]
plt.plot(x,y,linestyle="dashed")
plt.title("lineplot example")
plt.xlabel("x_axis")
plt.ylabel("y_axis")
plt.show()
