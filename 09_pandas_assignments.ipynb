# %%
#____________________________________________task___________________________________________________

# %%
import pandas as pd
df={
    
        'name':['harshit','hari','rahul','riya'],
        'age':[22,23,24,21],
        'exp':[1,2,3,4],
        'post':["clerk","clerk","cashier","hr"],
        'salary':[20000,25000,30000,35000]

    }

d=pd.DataFrame(df)
#d.iloc[:,0]#(only fethched coloumn at zero index)
#d.iloc[:,[1,4]]#(fetched first and fourth coloumn)
#d.iloc[[1,3]#(fetches the all values of 1 and 3)
#d.iloc[1,[0,2]]#(FETCHES THE  1 VALUE FROM THE 0 AND 2 COLOUMN)


d[d["age"]>=22].iloc[:,:]#(FETHES THE CONDITION APPLIED ON ALL COLOUMNS AND ALL ROWS )

# %%
#______________________________________________assignment1____________________________________________

# %%
import pandas as pd
d=pd.DataFrame(
    {
        "emp_id":[101,102,103,104,105],
        "name":['rahul',"anita","amit","neha","rohit"],
        "department":["it",'hr',"it","finance","hr"],
        "salary":[50000,45000,60000,55000,48000],
        "experience":[2,3,5,4,2]
    }
)
# print(d,"\n")
# q=d.iloc[:,[1,3]]
# print(q,"\n")
# w=d.iloc[0:3]
# print(w,'\n')
# e=d[d["department"]=="it"]
# print(e,"\n")
# r=d[d["salary"]>50000]
# print(r,"\n")
# d["bonus"]=d.loc[(d["experience"]>0),"salary"]*0.10
# print(d)
# y=d.agg({"name",["salary"]:"max"})
# print(y)
# u=d.sort_values(by=["salary"],ascending=True)
# print(u)
# d["new_salary"]=d.loc[(d["experience"]>=3),"salary"]+5000
# print(d)
# i=d["department"].value_counts()
# print(i)
o=d.rename(
    columns={
        "salary":"paycheck"
    }
)
print(o)

# %%
#__________________________________________assignment2____________________________________________

# %% [markdown]
# SERIES BASICS

# %%
#(1)
import pandas as pd
import numpy as np
l=[10,20,30,40,50]
df=pd.Series(np.array(l))
df
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#(2)
import pandas as pd
import numpy as np
l=[10,20,30,40,50]
df=pd.Series(np.array(l),index=["a","b","c","d","e"])
df
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
#(3)
import pandas as pd
import numpy as np
l=[10,20,30,40,50]
df=pd.Series(np.array(l),index=["a","b","c","d","e"])
d=df[2]
d
# Out:
# C:\Users\TECHCADD\AppData\Local\Temp\ipykernel_5584\2104461109.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d=df[2]
# np.int64(30)

# %%
#(4)
import pandas as pd
import numpy as np
l=[10,20,30,40,50]
df=pd.Series(np.array(l),index=["a","b","c","d","e"])
df["c"]="100" #or df[2]="100"
df
# Out:
# C:\Users\TECHCADD\AppData\Local\Temp\ipykernel_5584\226586627.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '100' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df["c"]="100" #or df[2]="100"
# a     10
# b     20
# c    100
# d     40
# e     50
# dtype: object

# %%
#(5)
import pandas as pd
import numpy as np
l=[10,20,30,40,50]
df=pd.Series(np.array(l),index=["a","b","c","d","e"])
df.describe()
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %% [markdown]
# DATA FRAME CREATION AND VIEWING

# %%
data={
    "name":["amit","priya","rahul","sneha"],
    "age":[23,25,22,24],
    "city":["delhi",'mumbai',"pune","chennai"]

}
d=pd.DataFrame(data)
d
# Out:
#     name  age     city
# 0   amit   23    delhi
# 1  priya   25   mumbai
# 2  rahul   22     pune
# 3  sneha   24  chennai

# %%
#(6)
d[0:2:]
# Out:
#     name  age    city
# 0   amit   23   delhi
# 1  priya   25  mumbai

# %%
#(7)
d.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
#(8)
d["score"]=d["score"]=(1,2,3,4)
d
# Out:
#     name  age     city  score
# 0   amit   23    delhi      1
# 1  priya   25   mumbai      2
# 2  rahul   22     pune      3
# 3  sneha   24  chennai      4

# %% [markdown]
# DATAFRAME INDEXING AND SELECTION

# %%
data={
    "name":["amit","priya","rahul","sneha"],
    "age":[23,25,22,24],
    "city":["delhi",'mumbai',"pune","chennai"]

}
d=pd.DataFrame(data)
d
# Out:
#     name  age     city
# 0   amit   23    delhi
# 1  priya   25   mumbai
# 2  rahul   22     pune
# 3  sneha   24  chennai

# %%
#(9)
d.iloc[:,[0,2]]
# Out:
#     name     city
# 0   amit    delhi
# 1  priya   mumbai
# 2  rahul     pune
# 3  sneha  chennai

# %%
#(10)
d.iloc[0:2,:]
# Out:
#     name  age    city
# 0   amit   23   delhi
# 1  priya   25  mumbai

# %%
#(11)
d[d["age"]>23]
# Out:
#     name  age     city
# 1  priya   25   mumbai
# 3  sneha   24  chennai

# %%
data={
    "name":["amit","priya","rahul","sneha"],
    "age":[23,25,22,24],
    "city":["delhi",'mumbai',"pune","chennai"]

}
d=pd.DataFrame(data)
d
# Out:
#     name  age     city
# 0   amit   23    delhi
# 1  priya   25   mumbai
# 2  rahul   22     pune
# 3  sneha   24  chennai

# %%
#(12)
d.loc[d['name']=='rahul','city']="banglore"
d
# Out:
#     name  age      city
# 0   amit   23     delhi
# 1  priya   25    mumbai
# 2  rahul   22  banglore
# 3  sneha   24   chennai

# %%
d=pd.read_csv(r"c:\Users\TECHCADD\Downloads\employee_salary_dataset.csv")
d
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
#(13)
d.groupby('Department')[['Monthly_Salary']].mean()
# Out:
#             Monthly_Salary
# Department
# Finance       67261.900000
# HR            82945.142857
# IT            76520.500000
# Marketing     96430.846154
# Operations    84239.900000

# %%
#(14)
d.groupby("Department")[["Monthly_Salary"]].agg(["min","max","mean"])
# Out:
#            Monthly_Salary
#                       min     max          mean
# Department
# Finance             28420  118179  67261.900000
# HR                  43589  134616  82945.142857
# IT                  30600  130983  76520.500000
# Marketing           30895  141381  96430.846154
# Operations          31893  149123  84239.900000

# %%
#(15)
d["bonus"]=d.loc[:,"Monthly_Salary"]*0.10
d
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
#(16)
import pandas as pd
df={
    
        'name':['harshit','hari','rahul','riya'],
        'age':[22,23,24,21],
        'e_id':[1,2,3,4],
       

    }

d=pd.DataFrame(df)

df1={

        "company":["google","infosys",'excel',"techadd"],
        "e_id":[6,8,2,1],
        'salary':[20000,25000,30000,35000],

}

f=pd.DataFrame(df1)

h=pd.merge(d,f,on="e_id",how="inner")
h
# Out:
#       name  age  e_id  company  salary
# 0  harshit   22     1  techadd   35000
# 1     hari   23     2    excel   30000

# %%
#(17)
import pandas as pd
df={
    
        'name':['harshit','hari','rahul','riya'],
        'age':[22,23,24,21],
        'exp':[1,2,3,4],
       

    }

d=pd.DataFrame(df)

df1={

        "company":["google","infosys",'excel',"techadd"],
        'post':["clerk","clerk","cashier","hr"],
        'salary':[20000,25000,30000,35000],

}

f=pd.DataFrame(df1)



pd.concat([d,f],axis=1)
# Out:
#       name  age  exp  company     post  salary
# 0  harshit   22    1   google    clerk   20000
# 1     hari   23    2  infosys    clerk   25000
# 2    rahul   24    3    excel  cashier   30000
# 3     riya   21    4  techadd       hr   35000

# %%
d=pd.read_csv(r"c:\Users\TECHCADD\Downloads\employee_salary_dataset.csv")
d
# Out:
#     EmployeeID         Name  Department  Experience_Years Education_Level  \
# 0            1   Employee_1   Marketing                15          Master
# 1            2   Employee_2  Operations                 7        Bachelor
# 2            3   Employee_3          IT                12     High School
# 3            4   Employee_4  Operations                 8             PhD
# 4            5   Employee_5  Operations                15          Master
# 5            6   Employee_6     Finance                 3     High School
# 6            7   Employee_7          IT                14             PhD
# 7            8   Employee_8          IT                17             PhD
# 8            9   Employee_9          IT                 4        Bachelor
# 9           10  Employee_10  Operations                18     High School
# 10          11  Employee_11   Marketing                 8             PhD
# 11          12  Employee_12          IT                 4          Master
# ...

# %%
#(18)
print(d.loc[:,['Name','Department',"Monthly_Salary"]])
# Out:
#            Name  Department  Monthly_Salary
# 0    Employee_1   Marketing          111416
# 1    Employee_2  Operations           95271
# 2    Employee_3          IT           69064
# 3    Employee_4  Operations           95091
# 4    Employee_5  Operations          132450
# 5    Employee_6     Finance           65818
# 6    Employee_7          IT           70525
# 7    Employee_8          IT           44830
# 8    Employee_9          IT           42429
# 9   Employee_10  Operations           31893
# 10  Employee_11   Marketing          141381
# 11  Employee_12          IT          104909
# 12  Employee_13  Operations           72333
# 13  Employee_14     Finance           28436
# 14  Employee_15   Marketing           99290
# 15  Employee_16     Finance          101213
# 16  Employee_17   Marketing           30895
# 17  Employee_18  Operations           44738
# 18  Employee_19          HR           55746
# 19  Employee_20   Marketing           74377
# ...

# %%
#(19)
d["City"].unique()
# Out:
# array(['Delhi', 'Bangalore', 'Hyderabad', 'Mumbai', 'Chennai'],
#       dtype=object)

# %%
import pandas as pd 
data={
    "name":["amit","priya","rahul","sneha"],
    "age":[23,25,22,24],
    "city":["delhi",'mumbai',"pune","chennai"]

}
d=pd.DataFrame(data)
d
# Out:
#     name  age     city
# 0   amit   23    delhi
# 1  priya   25   mumbai
# 2  rahul   22     pune
# 3  sneha   24  chennai

# %%
d["age"]=d["age",(dtype=="int")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d["age"]=d["age",dtype=="int"]
#
# NameError: name 'dtype' is not defined
